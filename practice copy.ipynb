# %%
import numpy as np 
import matplotlib.pyplot as plt 
import torch
imgs = np.load('imgs.npy')
imgs = torch.Tensor(imgs)

# %%
plt.imshow(np.array([[1,2],[2,3]]))

# %%
plt.imshow(imgs[0].permute(1,2,0).numpy()/255)

# %%
# Out:
# array([[[0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         ...,
#         [0.3137255 , 0.28627452, 0.25882354],
#         [0.31764707, 0.2901961 , 0.2627451 ],
#         [0.32941177, 0.3019608 , 0.27450982]],
#
#        [[0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         ...,
#         [0.3254902 , 0.29803923, 0.27058825],
#         [0.3372549 , 0.30980393, 0.28235295],
#         [0.35686275, 0.32941177, 0.3019608 ]],
#
#        [[0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         [0.27450982, 0.27450982, 0.27450982],
#         ...,
#         [0.3372549 , 0.30980393, 0.28235295],
#         [0.34901962, 0.32156864, 0.29411766],
#         [0.36862746, 0.34117648, 0.3137255 ]],
#
#        ...,
#
#        [[0.41960785, 0.41568628, 0.42745098],
# ...
